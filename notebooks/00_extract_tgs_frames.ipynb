# %%
# !pip install telethon pillow tqdm

# %% [markdown]
# #### Setup & Imports

# %%
from telethon import TelegramClient
from telethon.tl.types import InputStickerSetShortName

from pathlib import Path
from tqdm import tqdm
from PIL import Image
import hashlib
import json
import random
import os

# %% [markdown]
# ##### Configure Directories

# %%
BASE_DIR = Path("../data")
RAW_DIR = BASE_DIR / "stickers_raw_tgs"     # raw downloaded stickers (webp)
PNG_DIR = BASE_DIR / "stickers_png"         # converted + resized PNG
UNIQUE_DIR = BASE_DIR / "stickers_unique"   # deduplicated
META_PATH = BASE_DIR / "metadata.json"

for d in [RAW_DIR, PNG_DIR, UNIQUE_DIR]:
    d.mkdir(exist_ok=True)

print("Directories:")
print(" RAW_DIR    =", RAW_DIR)
print(" PNG_DIR    =", PNG_DIR)
print(" UNIQUE_DIR =", UNIQUE_DIR)
# Out:
# Directories:
#  RAW_DIR    = ../data/stickers_raw_tgs
#  PNG_DIR    = ../data/stickers_png
#  UNIQUE_DIR = ../data/stickers_unique

# %%
# !pip install dotenv

# %% [markdown]
# ##### Configure API keys

# %%
from dotenv import load_dotenv
import os
load_dotenv()

api_id = os.getenv('TELEGRAM_APP_ID')   # int
api_hash = os.getenv('TELEGRAM_APP_HASH')  # str

# Session name (local file to store login)
SESSION_NAME = "stickergen_session"

# %% [markdown]
# ##### Discover Top Sticker Packs

# %%
from telethon.tl.functions.messages import GetFeaturedStickersRequest, GetAllStickersRequest
from telethon.tl.types import InputStickerSetID

async def discover_top_sticker_packs(client, limit=100):
    """
    Discover popular sticker packs from Telegram.
    
    Uses multiple methods:
    1. Featured stickers (curated by Telegram)
    2. All installed stickers from user's account
    3. Trending stickers
    
    Returns list of (set_id, access_hash, title, short_name, count) tuples
    """
    discovered_sets = []
    seen_ids = set()
    
    print(f"Discovering top {limit} sticker packs...\n")
    
    # Method 1: Get featured/promoted sticker sets
    try:
        print("📦 Fetching featured stickers...")
        featured = await client(GetFeaturedStickersRequest(hash=0))
        
        for sticker_set_covered in featured.sets:
            sticker_set = sticker_set_covered.set
            if sticker_set.id not in seen_ids:
                seen_ids.add(sticker_set.id)
                discovered_sets.append({
                    'id': sticker_set.id,
                    'access_hash': sticker_set.access_hash,
                    'title': sticker_set.title,
                    'short_name': sticker_set.short_name,
                    'count': sticker_set.count,
                    'source': 'featured'
                })
        
        print(f"  ✓ Found {len(discovered_sets)} featured packs")
    except Exception as e:
        print(f"  ✗ Error fetching featured: {e}")
    
    # Method 2: Get all stickers (includes user's installed packs)
    try:
        print("\n📦 Fetching all available stickers...")
        all_stickers = await client(GetAllStickersRequest(hash=0))
        
        if hasattr(all_stickers, 'sets'):
            for sticker_set in all_stickers.sets:
                if sticker_set.id not in seen_ids:
                    seen_ids.add(sticker_set.id)
                    discovered_sets.append({
                        'id': sticker_set.id,
                        'access_hash': sticker_set.access_hash,
                        'title': sticker_set.title,
                        'short_name': sticker_set.short_name,
                        'count': sticker_set.count,
                        'source': 'all_stickers'
                    })
            
            print(f"  ✓ Found {len(discovered_sets) - len([s for s in discovered_sets if s['source'] == 'featured'])} additional packs")
    except Exception as e:
        print(f"  ✗ Error fetching all stickers: {e}")
    
    # Sort by sticker count (popularity indicator) and limit
    discovered_sets.sort(key=lambda x: x['count'], reverse=True)
    top_sets = discovered_sets[:limit]
    
    print(f"\n✓ Discovered {len(discovered_sets)} total packs")
    print(f"✓ Selected top {len(top_sets)} packs by size\n")
    
    # Print summary
    print("Top 10 packs:")
    for i, pack in enumerate(top_sets[:10], 1):
        print(f"  {i:2d}. {pack['title'][:40]:40s} | {pack['count']:3d} stickers | @{pack['short_name']}")
    
    if len(top_sets) > 10:
        print(f"  ... and {len(top_sets) - 10} more")
    
    return top_sets

# Run discovery
client = TelegramClient(SESSION_NAME, api_id, api_hash)

async with client:
    DISCOVERED_PACKS = await discover_top_sticker_packs(client, limit=1000)
# Out:
# Discovering top 1000 sticker packs...
#
# 📦 Fetching featured stickers...
#   ✓ Found 231 featured packs
#
# 📦 Fetching all available stickers...
#   ✓ Found 0 additional packs
#
# ✓ Discovered 231 total packs
# ✓ Selected top 231 packs by size
#
# Top 10 packs:
#    1. Funky Goose                              |  41 stickers | @FunkyGoose
#    2. Duck                                     |  40 stickers | @UtyaDuck
#    3. Sushi Cat                                |  38 stickers | @SushiCat
#    4. Fromg                                    |  38 stickers | @Fromg
#    5. Chibi-Chan                               |  38 stickers | @ChibiChan
#    6. Borzoi                                   |  38 stickers | @Borzoi
#    7. Colorful Messages                        |  37 stickers | @ColorfulMessages
#    8. Green Bun                                |  36 stickers | @GreenBun
#    9. Hands for Friends                        |  35 stickers | @Hands4Friends
# ...

# %%
from telethon.tl.functions.messages import GetStickerSetRequest
from telethon.tl.types import InputStickerSetShortName, InputStickerSetID

async def download_sticker_pack_by_id(client, pack_info, base_dir):
    """
    Download a sticker pack using its ID and access hash.
    
    Args:
        client: TelegramClient instance
        pack_info: Dict with 'id', 'access_hash', 'short_name', 'title'
        base_dir: Directory to save stickers
    """
    try:
        short_name = pack_info['short_name']
        print(f"📥 Downloading: {pack_info['title'][:50]} (@{short_name})")
        
        # Request sticker set details using ID
        sticker_set = await client(GetStickerSetRequest(
            stickerset=InputStickerSetID(
                id=pack_info['id'],
                access_hash=pack_info['access_hash']
            ),
            hash=0
        ))
        
        count = 0
        skipped = 0
        
        for i, doc in enumerate(sticker_set.documents):
            # Use short_name for filename
            out_path = base_dir / f"{short_name}_{i}.tgs"
            
            if out_path.exists():
                skipped += 1
                continue
            
            await client.download_media(doc, file=out_path)
            count += 1
        
        status = "✓" if count > 0 else "⊙"
        print(f"  {status} Downloaded {count} new stickers (skipped {skipped} existing)")
        return count
        
    except Exception as e:
        print(f"  ✗ Failed: {e}")
        return 0

async def download_discovered_packs(client, pack_list, base_dir, max_packs=100):
    """
    Download multiple discovered sticker packs.
    
    Args:
        client: TelegramClient instance
        pack_list: List of pack info dicts from discover_top_sticker_packs
        base_dir: Directory to save stickers
        max_packs: Maximum number of packs to download
    """
    base_dir = Path(base_dir)
    base_dir.mkdir(parents=True, exist_ok=True)
    
    total_stickers = 0
    successful_packs = 0
    
    print(f"\n{'='*70}")
    print(f"DOWNLOADING {min(len(pack_list), max_packs)} STICKER PACKS")
    print(f"{'='*70}\n")
    
    for i, pack_info in enumerate(pack_list[:max_packs], 1):
        print(f"[{i}/{min(len(pack_list), max_packs)}] ", end="")
        count = await download_sticker_pack_by_id(client, pack_info, base_dir)
        
        if count > 0:
            successful_packs += 1
            total_stickers += count
        
        # Be nice to Telegram servers
        import asyncio
        await asyncio.sleep(0.5)
    
    print(f"\n{'='*70}")
    print(f"DOWNLOAD COMPLETE!")
    print(f"{'='*70}")
    print(f"✓ Successfully downloaded: {successful_packs} packs")
    print(f"✓ Total stickers: {total_stickers}")
    print(f"✓ Saved to: {base_dir}")
    print(f"{'='*70}\n")

# Download the discovered packs
client = TelegramClient(SESSION_NAME, api_id, api_hash)

async with client:
    await download_discovered_packs(
        client, 
        DISCOVERED_PACKS, 
        RAW_DIR,
        max_packs=1000  # Download top 100 packs
    )
# Out:
# ...
# DOWNLOADING 231 STICKER PACKS
# ...
#
# [1/231] 📥 Downloading: Funky Goose (@FunkyGoose)
#   ⊙ Downloaded 0 new stickers (skipped 41 existing)
# [2/231] 📥 Downloading: Duck (@UtyaDuck)
#   ⊙ Downloaded 0 new stickers (skipped 40 existing)
# [3/231] 📥 Downloading: Sushi Cat (@SushiCat)
#   ⊙ Downloaded 0 new stickers (skipped 38 existing)
# [4/231] 📥 Downloading: Fromg (@Fromg)
#   ⊙ Downloaded 0 new stickers (skipped 38 existing)
# [5/231] 📥 Downloading: Chibi-Chan (@ChibiChan)
#   ⊙ Downloaded 0 new stickers (skipped 38 existing)
# [6/231] 📥 Downloading: Borzoi (@Borzoi)
#   ⊙ Downloaded 0 new stickers (skipped 38 existing)
# [7/231] 📥 Downloading: Colorful Messages (@ColorfulMessages)
#   ⊙ Downloaded 0 new stickers (skipped 37 existing)
# [8/231] 📥 Downloading: Green Bun (@GreenBun)
#   ⊙ Downloaded 0 new stickers (skipped 36 existing)
# [9/231] 📥 Downloading: Hands for Friends (@Hands4Friends)
#   ⊙ Downloaded 0 new stickers (skipped 35 existing)
# ...

# %% [markdown]
# ##### Convert tgs frames to png

# %%
import os
from pathlib import Path

from lottie.importers import importers
from lottie.exporters import exporters
from lottie.utils.stripper import float_strip, heavy_strip


def lottie_convert(
    infile: Path,
    out_dir: Path,
    fps=30,
    width=256,
    height=256,
    optimize=0,   # 0 = none, 1 = float strip, 2 = heavy strip
):
    """
    Convert TGS/Lottie animation to PNG frames.
    
    Returns:
        Path to output directory if successful, None if failed
    """
    infile = str(infile)
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    try:
        # ------------------------
        # 1. Select importer
        # ------------------------
        ext = os.path.splitext(infile)[1][1:]
        importer = None
        for imp in importers:
            if ext in imp.extensions:
                importer = imp
                break

        if importer is None:
            print(f"  ✗ Unsupported extension .{ext}: {infile}")
            return None

        animation = importer.process(infile)

        # Check for invalid/empty animations
        if animation is None:
            print(f"  ✗ Failed to load animation: {infile}")
            return None
        
        if not hasattr(animation, 'in_point') or not hasattr(animation, 'out_point'):
            print(f"  ✗ Animation missing time points: {infile}")
            return None
        
        # Check for zero-length animations
        animation_length = animation.out_point - animation.in_point
        if animation_length <= 0:
            print(f"  ✗ Zero-length animation (in={animation.in_point}, out={animation.out_point}): {infile}")
            return None

        # ------------------------
        # 2. FPS update
        # ------------------------
        if fps:
            animation.frame_rate = fps

        # ------------------------
        # 3. Resize
        # ------------------------
        if width or height:
            if width and not height:
                height = animation.height * (width / animation.width)
            if height and not width:
                width = animation.width * (height / animation.height)
            animation.scale(width, height)

        # ------------------------
        # 4. Optimization
        # ------------------------
        if optimize == 1:
            float_strip(animation)
        elif optimize == 2:
            heavy_strip(animation)

        # ------------------------
        # 5. Export frames with correct template
        # ------------------------
        exporter = exporters.get("png")

        # python-lottie frame template:
        #   "{frame}"  → replaced with 0, 1, 2, ...
        outfile_template = str(out_dir / "frame.png")

        exporter.process(animation, outfile_template)

        return out_dir
        
    except ZeroDivisionError as e:
        print(f"  ✗ Division by zero error (likely zero-length animation): {infile}")
        return None
    except Exception as e:
        print(f"  ✗ Error converting {infile}: {e}")
        return None


# Convert TGS to PNG frames using lottie
RAW_DIR = Path("../data/stickers_raw_tgs")
PNG_DIR = Path("../data/stickers_png")

tgs_files = list(RAW_DIR.glob("*.tgs"))
print(f"Found {len(tgs_files)} TGS files to convert\n")

successful = 0
failed = 0

for i, tgs in enumerate(tgs_files, 1):
    print(f"[{i}/{len(tgs_files)}] {tgs.name}", end=" ")
    output = PNG_DIR / tgs.stem
    
    result = lottie_convert(tgs, output)
    
    if result:
        # Count frames
        frame_count = len(list(output.glob("frame_*.png")))
        print(f"✓ {frame_count} frames")
        successful += 1
    else:
        failed += 1

print(f"\n{'='*60}")
print(f"CONVERSION COMPLETE")
print(f"{'='*60}")
print(f"✓ Successful: {successful}")
print(f"✗ Failed: {failed}")
print(f"{'='*60}")
# Out:
# Found 5973 TGS files to convert
#
# [1/5973] HomeElectronics_20.tgs ✓ 0 frames
# [2/5973] Flame_9.tgs ✓ 0 frames
# [3/5973] MagicMandrake_10.tgs ✓ 0 frames
# [4/5973] UtyaDuck_35.tgs ✓ 0 frames
# [5/5973] RedFox_2.tgs ✓ 0 frames
# [6/5973] MemesWithCats_28.tgs ✓ 0 frames
# [7/5973] Spaceman_6.tgs ✓ 0 frames
# [8/5973] Red_Squirrel_27.tgs ✓ 0 frames
# [9/5973] ColorfulJelly_24.tgs ✓ 0 frames
# [10/5973] OwledDidi_2.tgs ✓ 0 frames
# [11/5973] MrCat_1.tgs ✓ 0 frames
# [12/5973] CaptainWhale_10.tgs ✓ 180 frames
# [13/5973] TutterMouse_9.tgs ✓ 0 frames
# [14/5973] ToiletPaperBoy_17.tgs ✓ 0 frames
# [15/5973] NyaChan_6.tgs   ✗ Division by zero error (likely zero-length animation): ../data/stickers_raw_tgs/NyaChan_6.tgs
# [16/5973] knightbraveheart_7.tgs ✓ 0 frames
# [17/5973] Kozita_2.tgs ✓ 0 frames
# [18/5973] ChappyBunny_17.tgs ✓ 0 frames
# [19/5973] FishPuffer_24.tgs ✓ 0 frames
# [20/5973] MiaBunny_25.tgs ✓ 0 frames
# [21/5973] Joker_7.tgs ✓ 0 frames
# ...

# %%
import hashlib
from rlottie_python import LottieAnimation
from PIL import Image
from pathlib import Path

def extract_frames_from_tgs(tgs_path: Path, out_dir: Path, size=256):
    out_dir.mkdir(parents=True, exist_ok=True)

    seen_hashes = set()


    # Load Telegram TGS animation
    anim = LottieAnimation.from_tgs(str(tgs_path))
    total = anim.lottie_animation_get_totalframe()

    for i in range(total):
        frame = anim.render_pillow_frame(i)         # numpy array (H, W, 4)
        frame = frame.convert("RGBA").resize((size, size), Image.LANCZOS)
        pixel_hash = hashlib.md5(frame.tobytes()).hexdigest()
        if pixel_hash in seen_hashes:
            continue
        seen_hashes.add(pixel_hash)

        frame.save(out_dir / f"frame_{i:04d}.png")

RAW_DIR = Path("../data/stickers_raw_tgs")
PNG_DIR = Path("../data/stickers_png")

for tgs in RAW_DIR.glob("*.tgs"):
    extract_frames_from_tgs(tgs, PNG_DIR / tgs.stem)

# %% [markdown]
# ##### Save Unique Icons

# %%
import imagehash
from PIL import Image
from pathlib import Path

SRC_DIR = Path("../data/stickers_png")
OUT_DIR = Path("../data/icons_256")
OUT_DIR.mkdir(exist_ok=True)

TARGET_SIZE = 256

for sticker_dir in SRC_DIR.iterdir():
    if not sticker_dir.is_dir():
        continue

    frames = sorted(sticker_dir.glob("frame_*.png"))
    if not frames:
        continue

    sticker_name = sticker_dir.name
    unique_hashes = []
    out_index = 0

    for frame_path in frames:
        img = Image.open(frame_path).convert("RGBA")
        img = img.resize((TARGET_SIZE, TARGET_SIZE), Image.LANCZOS)

        # Perceptual hash for deduplication
        ph = imagehash.phash(img)

        # Skip near-duplicate frames
        if any(ph - uh < 5 for uh in unique_hashes):
            continue

        unique_hashes.append(ph)

        # Save as StickerName_00000.png
        out_file = OUT_DIR / f"{sticker_name}_{out_index:05d}.png"
        img.save(out_file)
        out_index += 1
